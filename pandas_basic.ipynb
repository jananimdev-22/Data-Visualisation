# %%
import pandas as pd
s=pd.Series([10,20,30,40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s=pd.Series([100,200,300] ,index=['A','B','C'])
print(s)
# Out:
# A    100
# B    200
# C    300
# dtype: int64

# %%
data={'maths':90,'physics':85,'chemistry':96}
s=pd.Series(data)
print(s)
iS=pd.Series([10,20,30,40])
print(s[0])
# Out:
# maths        90
# physics      85
# chemistry    96
# dtype: int64
# 90
# C:\Users\Ibscai04.DGVC-MCA\AppData\Local\Temp\ipykernel_11824\4040459880.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(s[0])

# %%
s=pd.Series([100,200,300],index=['A','B','C'])
print(s['B'])
print(s[['A','C']])
s=pd.Series([10,20,30,40])
print(s.size)
# Out:
# 200
# A    100
# C    300
# dtype: int64
# 4

# %%
print(s.shape)
# Out:
# (4,)

# %%
print(s.dtype)
# Out:
# int64

# %%
s=pd.Series([10,20,30,40])
print(s+10)
# Out:
# 0    20
# 1    30
# 2    40
# 3    50
# dtype: int64

# %%
print(s*2)
# Out:
# 0    20
# 1    40
# 2    60
# 3    80
# dtype: int64

# %%
print("sum=",s.sum())
print("mean=",s.mean())
print("maximum=",s.max())
print("minimum=",s.min())
# Out:
# sum= 100
# mean= 25.0
# maximum= 40
# minimum= 10

# %%
data={'roll no':[101,102,103],'name':['arun','priya','rahul'],'marks':[85,90,78]}
df=pd.DataFrame(data)
print(df)
# Out:
#    roll no   name  marks
# 0      101   arun     85
# 1      102  priya     90
# 2      103  rahul     78

# %%
print(df.shape)
print(df.columns)
print(df['name'])
# Out:
# (3, 3)
# Index(['roll no', 'name', 'marks'], dtype='object')
# 0     arun
# 1    priya
# 2    rahul
# Name: name, dtype: object

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
print(df.dtypes)
# Out:
# roll no     int64
# name       object
# marks       int64
# dtype: object

# %%
print(df[['name','marks']])
# Out:
#     name  marks
# 0   arun     85
# 1  priya     90
# 2  rahul     78

# %%
print(df.loc[0])
# Out:
# roll no     101
# name       arun
# marks        85
# Name: 0, dtype: object

# %%
print(df.loc[[0,2]])
# Out:
#    roll no   name  marks
# 0      101   arun     85
# 2      103  rahul     78

# %%
print(df.iloc[1])
# Out:
# roll no      102
# name       priya
# marks         90
# Name: 1, dtype: object

# %%
print(df.iloc[[0,2]])
# Out:
#    roll no   name  marks
# 0      101   arun     85
# 2      103  rahul     78

# %%
print(df.iloc[0:2,1:3])
# Out:
#     name  marks
# 0   arun     85
# 1  priya     90

# %%
df['grade']=['A','A+','B']
print(df)
# Out:
#    roll no   name  marks grade
# 0      101   arun     85     A
# 1      102  priya     90    A+
# 2      103  rahul     78     B

# %%
df['marks']=df['marks']+5
print(df)
# Out:
#    roll no   name  marks
# 0      101   arun    100
# 1      102  priya    105
# 2      103  rahul     93

# %%
df.drop('grade',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.drop('grade',axis=1,inplace=True)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
print(df)
# Out:
#    roll no   name  marks
# 0      101   arun     85
# 1      102  priya     90
# 2      103  rahul     78

# %%
print(df['marks'].sum())
# Out:
# 298

# %%
print(df['marks'].mean())
# Out:
# 99.33333333333333

# %%
print(df['marks'].max())
# Out:
# 105

# %%
print(df['marks'].min())
# Out:
# 93

# %%
df.sort_values('marks')
# Out:
#    roll no   name  marks
# 2      103  rahul     93
# 0      101   arun    100
# 1      102  priya    105

# %%
df.sort_values('marks',ascending=False)
# Out:
#    roll no   name  marks
# 1      102  priya    105
# 0      101   arun    100
# 2      103  rahul     93

# %%
import pandas as pd
data={'roll no':[101,102,103],'name':['arun','priya','rahul'],'marks':[85,90,78]}
df=pd.DataFrame(data)
print(df)
# Out:
#    roll no   name  marks
# 0      101   arun     85
# 1      102  priya     90
# 2      103  rahul     78

# %%
df.sort_values('marks')
# Out:
#    roll no   name  marks
# 2      103  rahul     78
# 0      101   arun     85
# 1      102  priya     90

# %%
df.sort_values('marks',ascending=False)
# Out:
#    roll no   name  marks
# 1      102  priya     90
# 0      101   arun     85
# 2      103  rahul     78

# %%
print(df[df['marks']>80])
# Out:
#    roll no   name  marks
# 0      101   arun     85
# 1      102  priya     90

# %%
print(df[df['marks']<90])
# Out:
#    roll no   name  marks
# 0      101   arun     85
# 2      103  rahul     78

# %%
data={'roll no':[101,102,103,104,105,106,107,108,109,110],'name':['arun','priya','rahul','ajay','pavi','ramesh','janani','darshan','hashu','varsha'],'marks':[85,90,78,67,99,77,82,79,90,78]}
df=pd.DataFrame(data)
print(df)
# Out:
#    roll no     name  marks
# 0      101     arun     85
# 1      102    priya     90
# 2      103    rahul     78
# 3      104     ajay     67
# 4      105     pavi     99
# 5      106   ramesh     77
# 6      107   janani     82
# 7      108  darshan     79
# 8      109    hashu     90
# 9      110   varsha     78

# %%
df.head()
# Out:
#    roll no   name  marks
# 0      101   arun     85
# 1      102  priya     90
# 2      103  rahul     78
# 3      104   ajay     67
# 4      105   pavi     99

# %%
df.tail()
# Out:
#    roll no     name  marks
# 5      106   ramesh     77
# 6      107   janani     82
# 7      108  darshan     79
# 8      109    hashu     90
# 9      110   varsha     78

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   roll no  10 non-null     int64
#  1   name     10 non-null     object
#  2   marks    10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 372.0+ bytes

# %%
df.describe()
# Out:
#          roll no      marks
# count   10.00000  10.000000
# mean   105.50000  82.500000
# std      3.02765   8.910044
# min    101.00000  67.000000
# 25%    103.25000  78.000000
# 50%    105.50000  80.500000
# 75%    107.75000  88.750000
# max    110.00000  99.000000
